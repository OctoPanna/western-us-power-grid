# %%
from importlib import reload
import src.data
import src.graph_utils
import cascade_failure.cascade_failure_DC
import src.visualization
import src.atack
reload(cascade_failure.cascade_failure_DC)
reload(src.data)
reload(src.graph_utils)
reload(src.visualization)
reload(src.atack)

from src.data import load_data_with_atributes
from cascade_failure.cascade_failure_DC import cascade_failure_DC
from src.visualization import draw_graph_after_failure
from src.atack import random_node_attack, high_capacity_node_attack, random_generator_node_attack, high_capacity_high_voltage_node_attack

# %%
G = load_data_with_atributes()
# Out:
# Graph loaded: 4941 nodes, 6594 edges

# %% [markdown]
# # DC model

# %% [markdown]
# ### No overloaded edges

# %%
result_after_attack = cascade_failure_DC(G0=G)

print("Iterations:", len(result_after_attack['history']))
for h in result_after_attack['history']:
    print(h['iteration'], "overloaded:", h['overloaded_count'])

failed_edges = []
for step in result_after_attack['history']:
    failed_edges.extend(step['overloaded_edges'])

draw_graph_after_failure(G_before=G, G_after=result_after_attack['graph'], failed_edges=failed_edges, title="DC Model Cascade Failure with no initial attack")
# Out:
# Iteration 0: num_edges = 6594
# Iterations: 1
# 0 overloaded: 0

# %%
failed_nodes = random_node_attack(G)
result_after_attack = cascade_failure_DC(G0=G, failed_nodes=failed_nodes)

print("Iterations:", len(result_after_attack['history']))
for h in result_after_attack['history']:
    print(h['iteration'], "overloaded:", h['overloaded_count'])

failed_edges = result_after_attack.get('failed_edges')

draw_graph_after_failure(G_before=G, G_after=result_after_attack['graph'], failed_edges=failed_edges, title="DC Model Cascade Failure with 1 Random Node Attack")
# Out:
# Initial failure of node 1542
# Initial failure of edge (1542, 1060) due to node 1542
# Initial failure of edge (1542, 1644) due to node 1542
# Initial failure of edge (1542, 1938) due to node 1542
# Iteration 0: num_edges = 6591
# Iterations: 2
# 0 overloaded: 1
# 0 overloaded: 0
# Failed nodes: {1542}
# Failed edges: [(1542, 1060), (1542, 1644), (1542, 1938)]

# %%
failed_nodes = random_node_attack(G, number_of_nodes=10)
result_after_attack = cascade_failure_DC(G0=G, failed_nodes=failed_nodes)

print("Iterations:", len(result_after_attack['history']))
for h in result_after_attack['history']:
    print(h['iteration'], "overloaded:", h['overloaded_count'])

failed_edges = result_after_attack.get('failed_edges')

draw_graph_after_failure(G_before=G, G_after=result_after_attack['graph'], failed_edges=failed_edges, title="DC Model Cascade Failure with 10 Random Node Attacks")
# Out:
# Initial failure of node 1397
# Initial failure of edge (1397, 1381) due to node 1397
# Initial failure of edge (1397, 1393) due to node 1397
# Initial failure of node 1196
# Initial failure of edge (1196, 1069) due to node 1196
# Initial failure of edge (1196, 1197) due to node 1196
# Initial failure of node 2247
# Initial failure of edge (2247, 2256) due to node 2247
# Initial failure of edge (2247, 2386) due to node 2247
# Initial failure of node 1923
# Initial failure of edge (1923, 1419) due to node 1923
# Initial failure of edge (1923, 1821) due to node 1923
# Initial failure of node 138
# Initial failure of edge (138, 205) due to node 138
# Initial failure of edge (138, 139) due to node 138
# Initial failure of edge (138, 140) due to node 138
# Initial failure of edge (138, 143) due to node 138
# Initial failure of edge (138, 150) due to node 138
# Initial failure of edge (138, 4882) due to node 138
# Initial failure of node 4163
# ...

# %%
failed_nodes = random_node_attack(G, number_of_nodes=100)
result_after_attack = cascade_failure_DC(G0=G, failed_nodes=failed_nodes)

print("Iterations:", len(result_after_attack['history']))
for h in result_after_attack['history']:
    print(h['iteration'], "overloaded:", h['overloaded_count'])

failed_edges = result_after_attack.get('failed_edges')

draw_graph_after_failure(G_before=G, G_after=result_after_attack['graph'], failed_edges=failed_edges, title="DC Model Cascade Failure with 100 Random Node Attacks")
# Out:
# Inital failures:
# node:  4595
# (4595, 4574)
# node:  4092
# (4092, 4091)
# (4092, 4116)
# (4092, 4189)
# (4092, 4208)
# node:  4813
# (4813, 4564)
# node:  2748
# (2748, 3083)
# node:  3189
# (3189, 2449)
# (3189, 2886)
# (3189, 3182)
# node:  362
# (362, 299)
# (362, 269)
# (362, 274)
# (362, 292)
# (362, 361)
# node:  1364
# (1364, 1203)
# (1364, 1342)
# (1364, 1350)
# node:  1939
# (1939, 1940)
# node:  1626
# (1626, 1272)
# (1626, 2003)
# node:  890
# (890, 902)
# (890, 929)
# node:  4686
# (4686, 4537)
# (4686, 4667)
# (4686, 4525)
# (4686, 4609)
# (4686, 4685)
# node:  3953
# (3953, 3983)
# (3953, 4000)
# node:  3629
# (3629, 3334)
# (3629, 3741)
# node:  208
# (208, 9)
# (208, 125)
# node:  1211
# (1211, 1210)
# node:  384
# (384, 383)
# (384, 393)
# (384, 426)
# (384, 447)
# node:  3402
# (3402, 3347)
# (3402, 3401)
# node:  4251
# (4251, 4161)
# node:  1880
# (1880, 1763)
# node:  3472
# (3472, 3329)
# (3472, 3344)
# node:  4494
# (4494, 4596)
# (4494, 4702)
# node:  2526
# ...

# %%
failed_nodes = high_capacity_node_attack(G, number_of_nodes=10)
result_after_attack = cascade_failure_DC(G0=G, failed_nodes=failed_nodes)

print("Iterations:", len(result_after_attack['history']))
for h in result_after_attack['history']:
    print(h['iteration'], "overloaded:", h['overloaded_count'])

failed_edges = result_after_attack.get('failed_edges')

draw_graph_after_failure(G_before=G, G_after=result_after_attack['graph'], failed_edges=failed_edges, title="DC Model Cascade Failure with 10 High Capacity Node Attacks")
# Out:
# Inital failures:
# node:  2617
# (2617, 2885)
# (2617, 2458)
# (2617, 2456)
# (2617, 2487)
# (2617, 2525)
# (2617, 2522)
# (2617, 2429)
# (2617, 2614)
# (2617, 2637)
# (2617, 2886)
# (2617, 2973)
# (2617, 2974)
# node:  1091
# (1091, 1065)
# (1091, 1086)
# (1091, 1088)
# (1091, 1090)
# (1091, 1092)
# (1091, 1166)
# (1091, 1353)
# (1091, 1429)
# (1091, 1504)
# (1091, 1525)
# node:  1166
# (1166, 1091)
# (1166, 1159)
# (1166, 1165)
# (1166, 1147)
# (1166, 1167)
# (1166, 1168)
# (1166, 1413)
# (1166, 1438)
# (1166, 1525)
# (1166, 1646)
# node:  2458
# (2458, 2459)
# (2458, 2457)
# (2458, 2456)
# (2458, 2487)
# (2458, 2525)
# (2458, 2593)
# (2458, 2617)
# (2458, 2677)
# (2458, 2703)
# node:  426
# (426, 384)
# (426, 420)
# (426, 425)
# (426, 427)
# (426, 447)
# (426, 3987)
# node:  4458
# (4458, 4459)
# (4458, 4448)
# (4458, 521)
# (4458, 569)
# (4458, 829)
# (4458, 837)
# (4458, 856)
# (4458, 4119)
# (4458, 2440)
# (4458, 4444)
# (4458, 4454)
# (4458, 4455)
# (4458, 4457)
# (4458, 514)
# ...

# %%
failed_nodes = high_capacity_node_attack(G, number_of_nodes=100)
result_after_attack = cascade_failure_DC(G0=G, failed_nodes=failed_nodes)

print("Iterations:", len(result_after_attack['history']))
for h in result_after_attack['history']:
    print(h['iteration'], "overloaded:", h['overloaded_count'])

failed_edges = result_after_attack.get('failed_edges')

draw_graph_after_failure(G_before=G, G_after=result_after_attack['graph'], failed_edges=failed_edges, title="DC Model Cascade Failure with 100 High Capacity Node Attacks")
# Out:
# Inital failures:
# node:  2617
# (2617, 2885)
# (2617, 2458)
# (2617, 2456)
# (2617, 2487)
# (2617, 2525)
# (2617, 2522)
# (2617, 2429)
# (2617, 2614)
# (2617, 2637)
# (2617, 2886)
# (2617, 2973)
# (2617, 2974)
# node:  1091
# (1091, 1065)
# (1091, 1086)
# (1091, 1088)
# (1091, 1090)
# (1091, 1092)
# (1091, 1166)
# (1091, 1353)
# (1091, 1429)
# (1091, 1504)
# (1091, 1525)
# node:  1166
# (1166, 1091)
# (1166, 1159)
# (1166, 1165)
# (1166, 1147)
# (1166, 1167)
# (1166, 1168)
# (1166, 1413)
# (1166, 1438)
# (1166, 1525)
# (1166, 1646)
# node:  2458
# (2458, 2459)
# (2458, 2457)
# (2458, 2456)
# (2458, 2487)
# (2458, 2525)
# (2458, 2593)
# (2458, 2617)
# (2458, 2677)
# (2458, 2703)
# node:  426
# (426, 384)
# (426, 420)
# (426, 425)
# (426, 427)
# (426, 447)
# (426, 3987)
# node:  4458
# (4458, 4459)
# (4458, 4448)
# (4458, 521)
# (4458, 569)
# (4458, 829)
# (4458, 837)
# (4458, 856)
# (4458, 4119)
# (4458, 2440)
# (4458, 4444)
# (4458, 4454)
# (4458, 4455)
# (4458, 4457)
# (4458, 514)
# ...

# %%
failed_nodes = random_generator_node_attack(G, number_of_nodes=100)
result_after_attack = cascade_failure_DC(G0=G, failed_nodes=failed_nodes)

print("Iterations:", len(result_after_attack['history']))
for h in result_after_attack['history']:
    print(h['iteration'], "overloaded:", h['overloaded_count'])

failed_edges = result_after_attack.get('failed_edges')

draw_graph_after_failure(G_before=G, G_after=result_after_attack['graph'], failed_edges=failed_edges, title="DC Model Cascade Failure with 100 Generator Node Attacks")
# Out:
# No more generator nodes to attack.
# Inital failures:
# node:  4461
# (4461, 24)
# (4461, 2562)
# (4461, 4446)
# (4461, 84)
# (4461, 132)
# (4461, 4460)
# node:  2298
# (2298, 2235)
# (2298, 2262)
# (2298, 2296)
# (2298, 2297)
# (2298, 2343)
# (2298, 2369)
# node:  4902
# (4902, 1033)
# (4902, 4879)
# (4902, 4901)
# node:  847
# (847, 846)
# (847, 848)
# (847, 911)
# node:  2605
# (2605, 2594)
# (2605, 2606)
# (2605, 2618)
# (2605, 2953)
# node:  2528
# (2528, 2543)
# (2528, 2486)
# (2528, 2549)
# (2528, 2606)
# (2528, 2612)
# (2528, 2804)
# node:  3782
# (3782, 3770)
# (3782, 3870)
# node:  1507
# (1507, 1506)
# (1507, 1244)
# (1507, 1541)
# node:  393
# (393, 384)
# (393, 395)
# (393, 396)
# (393, 447)
# (393, 2223)
# node:  396
# (396, 393)
# (396, 397)
# (396, 398)
# (396, 399)
# (396, 400)
# (396, 420)
# (396, 2231)
# (396, 2283)
# node:  2593
# (2593, 2459)
# (2593, 2458)
# (2593, 2567)
# (2593, 2569)
# (2593, 2572)
# (2593, 2704)
# (2593, 2909)
# node:  4041
# (4041, 3966)
# ...

# %%
failed_nodes = high_capacity_high_voltage_node_attack(G, number_of_nodes=100)
result_after_attack = cascade_failure_DC(G0=G, failed_nodes=failed_nodes)

print("Iterations:", len(result_after_attack['history']))
for h in result_after_attack['history']:
    print(h['iteration'], "overloaded:", h['overloaded_count'])

failed_edges = result_after_attack.get('failed_edges')

draw_graph_after_failure(G_before=G, G_after=result_after_attack['graph'], failed_edges=failed_edges, title="DC Model Cascade Failure with 100 High Capacity High Voltage Node Attacks")
# Out:
# Inital failures:
# node:  2617
# (2617, 2885)
# (2617, 2458)
# (2617, 2456)
# (2617, 2487)
# (2617, 2525)
# (2617, 2522)
# (2617, 2429)
# (2617, 2614)
# (2617, 2637)
# (2617, 2886)
# (2617, 2973)
# (2617, 2974)
# node:  2553
# (2553, 2874)
# (2553, 2843)
# (2553, 2870)
# (2553, 2871)
# (2553, 2872)
# (2553, 2908)
# (2553, 2721)
# (2553, 2801)
# (2553, 2809)
# (2553, 2845)
# (2553, 2922)
# (2553, 2971)
# (2553, 2995)
# (2553, 2999)
# (2553, 3096)
# (2553, 3128)
# (2553, 3141)
# (2553, 3149)
# (2553, 3284)
# node:  4458
# (4458, 4459)
# (4458, 4448)
# (4458, 521)
# (4458, 569)
# (4458, 829)
# (4458, 837)
# (4458, 856)
# (4458, 4119)
# (4458, 2440)
# (4458, 4444)
# (4458, 4454)
# (4458, 4455)
# (4458, 4457)
# (4458, 514)
# (4458, 4463)
# (4458, 4464)
# (4458, 4465)
# (4458, 4466)
# node:  1091
# (1091, 1065)
# (1091, 1086)
# (1091, 1088)
# (1091, 1090)
# (1091, 1092)
# (1091, 1166)
# (1091, 1353)
# (1091, 1429)
# (1091, 1504)
# (1091, 1525)
# node:  1166
# (1166, 1091)
# (1166, 1159)
# ...

# %%
failed_nodes = high_capacity_high_voltage_node_attack(G, number_of_nodes=200)
result_after_attack = cascade_failure_DC(G0=G, failed_nodes=failed_nodes)

print("Iterations:", len(result_after_attack['history']))
for h in result_after_attack['history']:
    print(h['iteration'], "overloaded:", h['overloaded_count'])

failed_edges = result_after_attack.get('failed_edges')

draw_graph_after_failure(G_before=G, G_after=result_after_attack['graph'], failed_edges=failed_edges, title="DC Model Cascade Failure with 200 High Capacity High Voltage Node Attacks")
# Out:
# Inital failures:
# node:  2617
# (2617, 2885)
# (2617, 2458)
# (2617, 2456)
# (2617, 2487)
# (2617, 2525)
# (2617, 2522)
# (2617, 2429)
# (2617, 2614)
# (2617, 2637)
# (2617, 2886)
# (2617, 2973)
# (2617, 2974)
# node:  2553
# (2553, 2874)
# (2553, 2843)
# (2553, 2870)
# (2553, 2871)
# (2553, 2872)
# (2553, 2908)
# (2553, 2721)
# (2553, 2801)
# (2553, 2809)
# (2553, 2845)
# (2553, 2922)
# (2553, 2971)
# (2553, 2995)
# (2553, 2999)
# (2553, 3096)
# (2553, 3128)
# (2553, 3141)
# (2553, 3149)
# (2553, 3284)
# node:  4458
# (4458, 4459)
# (4458, 4448)
# (4458, 521)
# (4458, 569)
# (4458, 829)
# (4458, 837)
# (4458, 856)
# (4458, 4119)
# (4458, 2440)
# (4458, 4444)
# (4458, 4454)
# (4458, 4455)
# (4458, 4457)
# (4458, 514)
# (4458, 4463)
# (4458, 4464)
# (4458, 4465)
# (4458, 4466)
# node:  1091
# (1091, 1065)
# (1091, 1086)
# (1091, 1088)
# (1091, 1090)
# (1091, 1092)
# (1091, 1166)
# (1091, 1353)
# (1091, 1429)
# (1091, 1504)
# (1091, 1525)
# node:  1166
# (1166, 1091)
# (1166, 1159)
# ...
